# %% [markdown]
# <a href="https://colab.research.google.com/github/cibelerusso/AnaliseMultivariadaEAprendizadoNaoSupervisionado/blob/master/1_An%C3%A1lise_descritiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd #
import numpy as np #biblioteca
from sklearn import datasets
# %matplotlib inline
import seaborn as sns

# %%
dados = datasets.load_iris()
dados = pd.DataFrame(iris['data'], columns=iris['feature_names'])
dados['species'] = iris['target']

# %% [markdown]
# ## Análise descritiva

# %%
dados.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# ## Análise descritiva agrupando por espécie

# %%
dados.groupby('species').describe().transpose()
# Out:
# species                          0          1          2
# sepal length (cm) count  50.000000  50.000000  50.000000
#                   mean    5.006000   5.936000   6.588000
#                   std     0.352490   0.516171   0.635880
#                   min     4.300000   4.900000   4.900000
#                   25%     4.800000   5.600000   6.225000
#                   50%     5.000000   5.900000   6.500000
#                   75%     5.200000   6.300000   6.900000
#                   max     5.800000   7.000000   7.900000
# sepal width (cm)  count  50.000000  50.000000  50.000000
#                   mean    3.428000   2.770000   2.974000
#                   std     0.379064   0.313798   0.322497
#                   min     2.300000   2.000000   2.200000
#                   25%     3.200000   2.525000   2.800000
#                   50%     3.400000   2.800000   3.000000
#                   75%     3.675000   3.000000   3.175000
# ...

# %% [markdown]
# ## Codificação de variável categórica para numérica

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
dados['species_numerica'] = le.fit_transform(dados['species'])

dados
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species  species_numerica
# ...

# %% [markdown]
# ## Padronização dos dados, caso necessário para a técnica

# %%
from sklearn.preprocessing import StandardScaler

# criar o objeto scaler
scaler = StandardScaler()

X = dados[['sepal length (cm)',	'sepal width (cm)',	'petal length (cm)',	'petal width (cm)']]

# normalizar a matriz X
X_norm = pd.DataFrame(scaler.fit_transform(X))

X_norm.describe()
# Out:
#                   0             1             2             3
# count  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02
# mean  -1.468455e-15 -1.823726e-15 -1.610564e-15 -9.473903e-16
# std    1.003350e+00  1.003350e+00  1.003350e+00  1.003350e+00
# min   -1.870024e+00 -2.433947e+00 -1.567576e+00 -1.447076e+00
# 25%   -9.006812e-01 -5.923730e-01 -1.226552e+00 -1.183812e+00
# 50%   -5.250608e-02 -1.319795e-01  3.364776e-01  1.325097e-01
# 75%    6.745011e-01  5.586108e-01  7.627583e-01  7.906707e-01
# max    2.492019e+00  3.090775e+00  1.785832e+00  1.712096e+00

# %% [markdown]
# ## Visualização de dados

# %%
dados
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species  species_numerica
# ...

# %%
data = dados.drop(['species_numerica'], axis=1)
sns.color_palette("colorblind")
sns.pairplot(data, hue='species', height=2, palette='colorblind')

# %% [markdown]
# # Outras visualizações: Gráfico de radar
#
# Veja os exemplos em:
#
# - https://www.pythoncharts.com/matplotlib/radar-charts/
#
# - https://aakashkh.github.io/python/visualisation/2019/08/26/Plotting-Seaborn-Radar.html

# %% [markdown]
# # Outras visualizações: Faces de Chernoff
#
# Veja os exemplos em:
#
# - https://pypi.org/project/ChernoffFace/
